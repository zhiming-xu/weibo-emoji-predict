# %%
import pandas as pd
import numpy as np
from mxnet import nd, autograd, gluon, init
from mxnet.gluon import nn, rnn
import gluonnlp as nlp
import jieba
import multiprocessing as mp
import time
from d2l import try_gpu

# %%
DATA_FOLDER = 'data/'
TRAIN_DATA = 'train.csv'
WORD_EMBED = 'sgns.weibo.word' 
N_ROWS=400
ctx = try_gpu()

# %%
train_df = pd.read_csv(DATA_FOLDER+TRAIN_DATA, nrows=N_ROWS, sep='|')

# %%
dataset =[ [row[0], row[1]] for _, row in train_df.iterrows()]
train_dataset, valid_dataset = nlp.data.train_valid_split(dataset, .2)
len(train_dataset), len(valid_dataset)
# Out:
# (320, 80)

# %%
def tokenizer(x):
    tweet, label = x
    word_list = jieba.lcut(tweet)
    return word_list, label

def to_word_list(dataset):
    start = time.time()

    with mp.Pool() as pool:
        # Each sample is processed in an asynchronous manner.
        dataset = gluon.data.ArrayDataset(pool.map(tokenizer, dataset))
    end = time.time()

    print('Done! Tokenizing Time={:.2f}s, #Sentences={}'.format(end - start, len(dataset)))
    return dataset

train_word_list = to_word_list(train_dataset)
valid_word_list = to_word_list(valid_dataset)
# Out:
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.259 seconds.
# Loading model cost 1.272 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.287 seconds.
# Loading model cost 1.285 seconds.
# Prefix dict has been built succesfully.
# Prefix dict has been built succesfully.
# Loading model cost 1.292 seconds.
# Prefix dict has been built succesfully.
# Prefix dict has been built succesfully.
# Loading model cost 1.296 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.329 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.335 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.336 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.337 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.347 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.347 seconds.
# Prefix dict has been built succesfully.
# Done! Tokenizing Time=1.66s, #Sentences=320
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Building prefix dict from the default dictionary ...
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model from cache /tmp/jieba.cache
# Loading model cost 1.240 seconds.
# Loading model cost 1.246 seconds.
# Prefix dict has been built succesfully.
# Prefix dict has been built succesfully.
# Loading model cost 1.260 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.288 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.291 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.297 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.313 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.321 seconds.
# Loading model cost 1.317 seconds.
# Prefix dict has been built succesfully.
# Prefix dict has been built succesfully.
# Loading model cost 1.326 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.334 seconds.
# Prefix dict has been built succesfully.
# Loading model cost 1.373 seconds.
# Prefix dict has been built succesfully.
# Done! Tokenizing Time=1.63s, #Sentences=80

# %%
word2vec = {}
start = time.time()
with open(DATA_FOLDER+WORD_EMBED, 'r') as word_embedding:
    for line in word_embedding:
        line_list = line.split()
        key = line_list.pop(0)
        word2vec[key] = line_list
end = time.time()
print('Done! Build Word2Vec Dictionary Time={:.2f}s, #Words={}'.format(end - start, len(word2vec)))
# Out:
# Done! Build Word2Vec Dictionary Time=5.82s, #Words=195196

# %%
word2vec['编']
# Out:
# ['-0.089650',
#  '-0.136879',
#  '0.236570',
#  '-0.241400',
#  '-0.147118',
#  '-0.156874',
#  '0.007496',
#  '-0.572064',
#  '0.050639',
#  '0.131918',
#  '-0.338594',
#  '0.004765',
#  '-0.092522',
#  '-0.118641',
#  '-0.342813',
#  '0.105665',
#  '0.095237',
#  '-0.094141',
#  '0.313450',
#  '0.114534',
#  '0.188237',
#  '-0.069500',
#  '-0.179199',
#  '-0.416745',
#  '0.067048',
#  '-0.008676',
#  '0.067986',
#  '-0.266693',
#  '0.177025',
#  '-0.158702',
#  '-0.200488',
#  '-0.462382',
#  '0.013249',
#  '-0.075613',
#  '0.049174',
#  '0.031828',
#  '0.023623',
#  '0.417893',
#  '-0.410313',
#  '-0.093464',
#  '-0.065177',
#  '0.281377',
#  '-0.168511',
#  '-0.296368',
#  '0.198455',
#  '-0.209229',
#  '-0.352531',
#  '0.279624',
#  '0.064723',
#  '-0.261250',
#  '0.144931',
#  '-0.140760',
#  '0.324439',
#  '0.308894',
#  '-0.582828',
#  '0.034167',
#  '-0.163485',
#  '-0.419896',
#  '-0.107867',
#  '-0.217759',
#  '-0.296049',
#  '0.455381',
#  '-0.078999',
#  '0.337311',
#  '0.288635',
#  '-0.017536',
#  '-0.158363',
#  '-0.158953',
#  '0.236532',
#  '-0.048226',
#  '-0.054832',
#  '0.016326',
#  '0.045263',
#  '-0.043543',
#  '-0.350490',
#  '0.082792',
#  '-0.308962',
#  '0.108073',
#  '0.020327',
#  '-0.430034',
#  '0.162017',
#  '0.519053',
#  '0.362968',
#  '0.093165',
#  '0.151538',
#  '0.100788',
#  '0.081603',
#  '-0.015363',
#  '-0.268391',
#  '-0.046033',
#  '0.263242',
#  '0.436935',
#  '0.130483',
#  '-0.001721',
#  '-0.234192',
#  '0.119173',
#  '0.049083',
#  '-0.101228',
#  '0.037915',
#  '0.038006',
#  '-0.042604',
#  '0.566892',
#  '-0.266652',
#  '0.026465',
#  '-0.183700',
#  '0.008828',
#  '0.021195',
#  '0.012809',
#  '0.129718',
#  '-0.303628',
#  '0.142486',
#  '0.146964',
#  '0.227395',
#  '-0.294684',
#  '0.571897',
#  '-0.519016',
#  '0.012423',
#  '-0.063141',
#  '0.105567',
#  '0.169401',
#  '0.047028',
#  '-0.219723',
#  '0.509989',
#  '-0.662860',
#  '-0.335446',
#  '-0.221004',
#  '0.867546',
#  '-0.027926',
#  '-0.131629',
#  '-0.109123',
#  '0.001558',
#  '-0.067642',
#  '-0.073185',
#  '0.035052',
#  '0.093015',
#  '0.004980',
#  '-0.138450',
#  '0.323437',
#  '0.315184',
#  '-0.547694',
#  '-0.287823',
#  '0.024389',
#  '0.173612',
#  '0.004908',
#  '-0.082790',
#  '0.005281',
#  '0.343669',
#  '-0.221545',
#  '-0.022711',
#  '0.155566',
#  '-0.354766',
#  '-0.125819',
#  '0.440961',
#  '0.432838',
#  '0.162697',
#  '-0.292201',
#  '0.322890',
#  '0.295445',
#  '-0.133488',
#  '0.109925',
#  '0.029793',
#  '-0.125924',
#  '-0.019739',
#  '-0.132360',
#  '-0.027802',
#  '0.097192',
#  '0.395853',
#  '0.346509',
#  '0.290596',
#  '0.022893',
#  '0.219741',
#  '0.317362',
#  '0.037991',
#  '-0.114821',
#  '0.087382',
#  '-0.364726',
#  '0.300093',
#  '-0.267395',
#  '-0.261063',
#  '0.124596',
#  '0.359444',
#  '0.357307',
#  '-0.317862',
#  '0.140043',
#  '-0.185203',
#  '0.165264',
#  '0.494900',
#  '0.048076',
#  '-0.317780',
#  '-0.470532',
#  '-0.016750',
#  '0.034083',
#  '0.054650',
#  '0.133437',
#  '0.491466',
#  '0.340268',
#  '-0.112515',
#  '0.163708',
#  '-0.474562',
#  '-0.345294',
#  '0.156322',
#  '0.220480',
#  '-0.412211',
#  '-0.105490',
#  '-0.093157',
#  '-0.043863',
#  '-0.407950',
#  '-0.471330',
#  '0.011164',
#  '-0.243440',
#  '-0.243053',
#  '-0.335658',
#  '0.454330',
#  '-0.059273',
#  '-0.102594',
#  '0.143363',
#  '-0.209529',
#  '-0.045368',
#  '-0.007327',
#  '0.106412',
#  '0.102428',
#  '0.224739',
#  '-0.222596',
#  '-0.387246',
#  '0.378361',
#  '-0.781801',
#  '0.222129',
#  '0.055456',
#  '0.014953',
#  '-0.015935',
#  '0.118742',
#  '0.303965',
#  '0.242951',
#  '-0.142315',
#  '0.182410',
#  '0.083338',
#  '0.313377',
#  '-0.411257',
#  '-0.403586',
#  '0.003954',
#  '0.273242',
#  '0.180388',
#  '-0.043261',
#  '0.061655',
#  '0.153876',
#  '0.060463',
#  '-0.261781',
#  '0.134884',
#  '0.400651',
#  '-0.125304',
#  '0.294522',
#  '0.334225',
#  '0.333309',
#  '0.184809',
#  '-0.205160',
#  '0.431342',
#  '-0.423397',
#  '0.072923',
#  '0.221466',
#  '-0.261022',
#  '0.176481',
#  '-0.132431',
#  '0.045326',
#  '0.022958',
#  '-0.163706',
#  '-0.021281',
#  '0.326364',
#  '-0.283096',
#  '0.350376',
#  '0.234812',
#  '0.501819',
#  '0.155370',
#  '0.063514',
#  '0.127403',
#  '0.073162',
#  '-0.667546',
#  '0.114957',
#  '0.223875',
#  '0.029311',
#  '-0.191222',
#  '0.127635',
#  '-0.145899',
#  '0.367076',
#  '-0.113159',
#  '-0.079080',
#  '0.245801',
#  '-0.466356',
#  '-0.607754',
#  '-0.206258',
#  '0.266252',
#  '-0.059405',
#  '0.554305',
#  '-0.430660',
#  '0.053139',
#  '-0.644757',
#  '-0.382536',
#  '-0.135216',
#  '-0.410263',
#  '-0.283274',
#  '-0.042017']
